# %%
import pandas as pd
from ydata_profiling import ProfileReport
from sklearn.impute import SimpleImputer, KNNImputer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 from ydata_profiling import ProfileReport
#       3 from sklearn.impute import SimpleImputer, KNNImputer
#
# ModuleNotFoundError: No module named 'ydata_profiling'

# %%
pip install ydata_profiling
# Out:
# Collecting ydata_profiling
#   Downloading ydata_profiling-4.18.4-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: scipy<1.17,>=1.8 in c:\users\lenovo\anaconda3\lib\site-packages (from ydata_profiling) (1.16.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in c:\users\lenovo\anaconda3\lib\site-packages (from ydata_profiling) (2.3.3)
# Collecting matplotlib<=3.10,>=3.5 (from ydata_profiling)
#   Downloading matplotlib-3.10.0-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from ydata_profiling) (2.12.4)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in c:\users\lenovo\anaconda3\lib\site-packages (from ydata_profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in c:\users\lenovo\anaconda3\lib\site-packages (from ydata_profiling) (3.1.6)
# Collecting visions<0.8.2,>=0.7.5 (from visions[type_image_path]<0.8.2,>=0.7.5->ydata_profiling)
#   Downloading visions-0.8.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.4,>=1.22 in c:\users\lenovo\anaconda3\lib\site-packages (from ydata_profiling) (2.3.5)
# Collecting minify-html>=0.15.0 (from ydata_profiling)
#   Downloading minify_html-0.18.1-cp313-cp313-win_amd64.whl.metadata (18 kB)
# Collecting filetype>=1.0.0 (from ydata_profiling)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting phik<0.13,>=0.12.5 (from ydata_profiling)
#   Downloading phik-0.12.5-cp313-cp313-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: requests<3,>=2.32.0 in c:\users\lenovo\anaconda3\lib\site-packages (from ydata_profiling) (2.32.5)
# Requirement already satisfied: tqdm<5,>=4.66.3 in c:\users\lenovo\anaconda3\lib\site-packages (from ydata_profiling) (4.70.0)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\users\lenovo\anaconda3\lib\site-packages (from ydata_profiling) (0.13.2)
# Collecting multimethod<2,>=1.4 (from ydata_profiling)
#   Downloading multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\lenovo\anaconda3\lib\site-packages (from ydata_profiling) (0.14.5)
# Requirement already satisfied: typeguard<5,>=4 in c:\users\lenovo\anaconda3\lib\site-packages (from ydata_profiling) (4.6.0)
# Collecting imagehash==4.3.2 (from ydata_profiling)
#   Downloading ImageHash-4.3.2-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting wordcloud>=1.9.4 (from ydata_profiling)
#   Downloading wordcloud-1.9.6-cp313-cp313-win_amd64.whl.metadata (3.5 kB)
# Collecting dacite<2,>=1.9 (from ydata_profiling)
#   Downloading dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numba<0.63,>=0.60 in c:\users\lenovo\anaconda3\lib\site-packages (from ydata_profiling) (0.62.1)
# Requirement already satisfied: PyWavelets in c:\users\lenovo\anaconda3\lib\site-packages (from imagehash==4.3.2->ydata_profiling) (1.9.0)
# Requirement already satisfied: pillow in c:\users\lenovo\anaconda3\lib\site-packages (from imagehash==4.3.2->ydata_profiling) (12.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from jinja2<3.2,>=3.1.6->ydata_profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in c:\users\lenovo\anaconda3\lib\site-packages (from numba<0.63,>=0.60->ydata_profiling) (0.45.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata_profiling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata_profiling) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\lenovo\anaconda3\lib\site-packages (from phik<0.13,>=0.12.5->ydata_profiling) (1.5.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic<3,>=2->ydata_profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic<3,>=2->ydata_profiling) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic<3,>=2->ydata_profiling) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic<3,>=2->ydata_profiling) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata_profiling) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata_profiling) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata_profiling) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata_profiling) (2026.7.22)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\lenovo\anaconda3\lib\site-packages (from statsmodels<1,>=0.13.2->ydata_profiling) (1.0.1)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\lib\site-packages (from tqdm<5,>=4.66.3->ydata_profiling) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata_profiling) (25.4.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\lenovo\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata_profiling) (3.5)
# Collecting puremagic (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata_profiling)
#   Downloading puremagic-2.2.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata_profiling) (1.17.0)
# Downloading ydata_profiling-4.18.4-py2.py3-none-any.whl (400 kB)
# Downloading ImageHash-4.3.2-py2.py3-none-any.whl (296 kB)
# Downloading dacite-1.9.2-py3-none-any.whl (16 kB)
# Downloading matplotlib-3.10.0-cp313-cp313-win_amd64.whl (8.0 MB)
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ---------------- ----------------------- 3.4/8.0 MB 21.6 MB/s eta 0:00:01
#    ------------------------------- -------- 6.3/8.0 MB 15.1 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 14.3 MB/s  0:00:00
# Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Downloading phik-0.12.5-cp313-cp313-win_amd64.whl (678 kB)
#    ---------------------------------------- 0.0/678.1 kB ? eta -:--:--
#    ---------------------------------------- 678.1/678.1 kB 12.5 MB/s  0:00:00
# Downloading visions-0.8.1-py3-none-any.whl (105 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading minify_html-0.18.1-cp313-cp313-win_amd64.whl (3.1 MB)
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    ---------------------------------------- 3.1/3.1 MB 19.1 MB/s  0:00:00
# Downloading wordcloud-1.9.6-cp313-cp313-win_amd64.whl (306 kB)
# Downloading puremagic-2.2.0-py3-none-any.whl (71 kB)
# Installing collected packages: minify-html, filetype, puremagic, multimethod, dacite, matplotlib, imagehash, wordcloud, visions, phik, ydata_profiling
#
#    ----------------------------------------  0/11 [minify-html]
#    ------- --------------------------------  2/11 [puremagic]
#    ---------- -----------------------------  3/11 [multimethod]
#   Attempting uninstall: matplotlib
#    ---------- -----------------------------  3/11 [multimethod]
#     Found existing installation: matplotlib 3.10.6
#    ---------- -----------------------------  3/11 [multimethod]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#     Uninstalling matplotlib-3.10.6:
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#       Successfully uninstalled matplotlib-3.10.6
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    ------------------ ---------------------  5/11 [matplotlib]
#    --------------------- ------------------  6/11 [imagehash]
#    ----------------------------- ----------  8/11 [visions]
#    ----------------------------- ----------  8/11 [visions]
#    ----------------------------- ----------  8/11 [visions]
#    ----------------------------- ----------  8/11 [visions]
#    ----------------------------- ----------  8/11 [visions]
#    ----------------------------- ----------  8/11 [visions]
#    ----------------------------- ----------  8/11 [visions]
#    ----------------------------- ----------  8/11 [visions]
#    ----------------------------- ----------  8/11 [visions]
#    ----------------------------- ----------  8/11 [visions]
#    -------------------------------- -------  9/11 [phik]
#    -------------------------------- -------  9/11 [phik]
#    ------------------------------------ --- 10/11 [ydata_profiling]
#    ------------------------------------ --- 10/11 [ydata_profiling]
#    ------------------------------------ --- 10/11 [ydata_profiling]
#    ------------------------------------ --- 10/11 [ydata_profiling]
#    ------------------------------------ --- 10/11 [ydata_profiling]
#    ------------------------------------ --- 10/11 [ydata_profiling]
#    ------------------------------------ --- 10/11 [ydata_profiling]
#    ------------------------------------ --- 10/11 [ydata_profiling]
#    ------------------------------------ --- 10/11 [ydata_profiling]
#    ------------------------------------ --- 10/11 [ydata_profiling]
#    ------------------------------------ --- 10/11 [ydata_profiling]
#    ------------------------------------ --- 10/11 [ydata_profiling]
#    ---------------------------------------- 11/11 [ydata_profiling]
#
# Successfully installed dacite-1.9.2 filetype-1.2.0 imagehash-4.3.2 matplotlib-3.10.0 minify-html-0.18.1 multimethod-1.12 phik-0.12.5 puremagic-2.2.0 visions-0.8.1 wordcloud-1.9.6 ydata_profiling-4.18.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from ydata_profiling import ProfileReport
from sklearn.impute import SimpleImputer, KNNImputer
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18988\3986002796.py:2: DeprecationWarning:
#     `import ydata_profiling` is deprecated and will not receive more updates.
#     Please install fg-data-profiling via `pip install fg-data-profiling` and use `import data_profiling` instead.
#
#   from ydata_profiling import ProfileReport

# %%
import pandas as pd
from ydata_profiling import ProfileReport
from sklearn.impute import SimpleImputer, KNNImputer
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_6632\3986002796.py:2: DeprecationWarning:
#     `import ydata_profiling` is deprecated and will not receive more updates.
#     Please install fg-data-profiling via `pip install fg-data-profiling` and use `import data_profiling` instead.
#
#   from ydata_profiling import ProfileReport

# %%
# !pip install fg-data-profiling
# Out:
# Collecting fg-data-profiling
#   Downloading fg_data_profiling-4.19.1-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: scipy<1.17,>=1.8 in c:\users\lenovo\anaconda3\lib\site-packages (from fg-data-profiling) (1.16.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in c:\users\lenovo\anaconda3\lib\site-packages (from fg-data-profiling) (2.3.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in c:\users\lenovo\anaconda3\lib\site-packages (from fg-data-profiling) (3.10.0)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from fg-data-profiling) (2.12.4)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in c:\users\lenovo\anaconda3\lib\site-packages (from fg-data-profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in c:\users\lenovo\anaconda3\lib\site-packages (from fg-data-profiling) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in c:\users\lenovo\anaconda3\lib\site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->fg-data-profiling) (0.8.1)
# Requirement already satisfied: numpy<2.4,>=1.22 in c:\users\lenovo\anaconda3\lib\site-packages (from fg-data-profiling) (2.3.5)
# Requirement already satisfied: minify-html>=0.15.0 in c:\users\lenovo\anaconda3\lib\site-packages (from fg-data-profiling) (0.18.1)
# Requirement already satisfied: filetype>=1.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from fg-data-profiling) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.12.5 in c:\users\lenovo\anaconda3\lib\site-packages (from fg-data-profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.32.0 in c:\users\lenovo\anaconda3\lib\site-packages (from fg-data-profiling) (2.32.5)
# Requirement already satisfied: tqdm<5,>=4.66.3 in c:\users\lenovo\anaconda3\lib\site-packages (from fg-data-profiling) (4.70.0)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\users\lenovo\anaconda3\lib\site-packages (from fg-data-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\users\lenovo\anaconda3\lib\site-packages (from fg-data-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\lenovo\anaconda3\lib\site-packages (from fg-data-profiling) (0.14.5)
# Requirement already satisfied: typeguard<5,>=4 in c:\users\lenovo\anaconda3\lib\site-packages (from fg-data-profiling) (4.6.0)
# Requirement already satisfied: imagehash==4.3.2 in c:\users\lenovo\anaconda3\lib\site-packages (from fg-data-profiling) (4.3.2)
# Requirement already satisfied: wordcloud>=1.9.4 in c:\users\lenovo\anaconda3\lib\site-packages (from fg-data-profiling) (1.9.6)
# Requirement already satisfied: dacite<2,>=1.9 in c:\users\lenovo\anaconda3\lib\site-packages (from fg-data-profiling) (1.9.2)
# Requirement already satisfied: numba<0.63,>=0.60 in c:\users\lenovo\anaconda3\lib\site-packages (from fg-data-profiling) (0.62.1)
# Requirement already satisfied: PyWavelets in c:\users\lenovo\anaconda3\lib\site-packages (from imagehash==4.3.2->fg-data-profiling) (1.9.0)
# Requirement already satisfied: pillow in c:\users\lenovo\anaconda3\lib\site-packages (from imagehash==4.3.2->fg-data-profiling) (12.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from jinja2<3.2,>=3.1.6->fg-data-profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->fg-data-profiling) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->fg-data-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->fg-data-profiling) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->fg-data-profiling) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->fg-data-profiling) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->fg-data-profiling) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->fg-data-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in c:\users\lenovo\anaconda3\lib\site-packages (from numba<0.63,>=0.60->fg-data-profiling) (0.45.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->fg-data-profiling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->fg-data-profiling) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\lenovo\anaconda3\lib\site-packages (from phik<0.13,>=0.12.5->fg-data-profiling) (1.5.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic<3,>=2->fg-data-profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic<3,>=2->fg-data-profiling) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic<3,>=2->fg-data-profiling) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic<3,>=2->fg-data-profiling) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests<3,>=2.32.0->fg-data-profiling) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from requests<3,>=2.32.0->fg-data-profiling) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\anaconda3\lib\site-packages (from requests<3,>=2.32.0->fg-data-profiling) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from requests<3,>=2.32.0->fg-data-profiling) (2026.7.22)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\lenovo\anaconda3\lib\site-packages (from statsmodels<1,>=0.13.2->fg-data-profiling) (1.0.1)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\lib\site-packages (from tqdm<5,>=4.66.3->fg-data-profiling) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->fg-data-profiling) (25.4.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\lenovo\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->fg-data-profiling) (3.5)
# Requirement already satisfied: puremagic in c:\users\lenovo\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->fg-data-profiling) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->fg-data-profiling) (1.17.0)
# Downloading fg_data_profiling-4.19.1-py2.py3-none-any.whl (400 kB)
# Installing collected packages: fg-data-profiling
# Successfully installed fg-data-profiling-4.19.1

# %%
import pandas as pd
from ydata_profiling import ProfileReport
from sklearn.impute import SimpleImputer, KNNImputer

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Lenovo\perovskites_data.csv")

df.head()
# Out:
#   Material_ID Formula  Bandgap  Formation_Energy     Volume
# 0  mp-1183115  AcAlO3   4.1024         -3.690019  57.451413
# 1  mp-1183052   AcBO3   0.8071         -2.475390  51.548126
# 2   mp-866101  AcCrO3   2.0031         -3.138972  61.362845
# 3   mp-864606  AcCuO3   0.0000         -2.422892  59.929387
# 4   mp-861502  AcFeO3   1.0084         -2.771539  61.797311

# %%
# 2. Generate the Automated Profiling Report
profile = ProfileReport(df, title="Perovskites Data Profiling Report")
profile.to_file("perovskites_report.html")
print("✅ Profiling report generated and saved as HTML.")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 5/5 [00:00<00:00, 21.70it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# ✅ Profiling report generated and saved as HTML.

# %%
# 3. Handle Missing Values: Mean Imputation
mean_imputer = SimpleImputer(strategy='mean')
df_mean_imputed = df.copy()
# Assuming 'Bandgap' has missing values
df_mean_imputed[['Bandgap']] = mean_imputer.fit_transform(df[['Bandgap']])

# %%
# 4. Handle Missing Values: KNN Imputation
knn_imputer = KNNImputer(n_neighbors=5)
df_knn_imputed = df.copy()
df_knn_imputed[['Bandgap']] = knn_imputer.fit_transform(df[['Bandgap']])

print("✅ Missing data successfully imputed using Mean and KNN strategies.")
# Out:
# ✅ Missing data successfully imputed using Mean and KNN strategies.

# %%
profile.to_file(r"C:\Users\Lenovo\perovskites_report.html")

print("HTML report saved successfully!")
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# HTML report saved successfully!
