# %%
pip install mp_api
# Out:
# Requirement already satisfied: mp_api in c:\users\lenovo\anaconda3\lib\site-packages (0.46.4)
# Requirement already satisfied: pymatgen>2024.2.20 in c:\users\lenovo\anaconda3\lib\site-packages (from mp_api) (2026.5.4)
# Requirement already satisfied: typing-extensions>=3.7.4.1 in c:\users\lenovo\anaconda3\lib\site-packages (from mp_api) (4.15.0)
# Requirement already satisfied: requests>=2.23.0 in c:\users\lenovo\anaconda3\lib\site-packages (from mp_api) (2.32.5)
# Requirement already satisfied: monty>=2024.12.10 in c:\users\lenovo\anaconda3\lib\site-packages (from mp_api) (2026.7.16)
# Requirement already satisfied: emmet-core>=0.87.1 in c:\users\lenovo\anaconda3\lib\site-packages (from mp_api) (0.87.1)
# Requirement already satisfied: boto3 in c:\users\lenovo\anaconda3\lib\site-packages (from mp_api) (1.43.67)
# Requirement already satisfied: orjson<4,>=3.10 in c:\users\lenovo\anaconda3\lib\site-packages (from mp_api) (3.11.9)
# Requirement already satisfied: pyarrow>=20.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from mp_api) (21.0.0)
# Requirement already satisfied: deltalake<1.6.0,>=1.4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from mp_api) (1.5.1)
# Requirement already satisfied: arro3-core>=0.5.0 in c:\users\lenovo\anaconda3\lib\site-packages (from deltalake<1.6.0,>=1.4.0->mp_api) (0.8.1)
# Requirement already satisfied: deprecated>=1.2.18 in c:\users\lenovo\anaconda3\lib\site-packages (from deltalake<1.6.0,>=1.4.0->mp_api) (1.3.1)
# Requirement already satisfied: wrapt<3,>=1.10 in c:\users\lenovo\anaconda3\lib\site-packages (from deprecated>=1.2.18->deltalake<1.6.0,>=1.4.0->mp_api) (1.17.0)
# Requirement already satisfied: pydantic>=2.12 in c:\users\lenovo\anaconda3\lib\site-packages (from emmet-core>=0.87.1->mp_api) (2.12.4)
# Requirement already satisfied: pydantic-settings>=2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from emmet-core>=0.87.1->mp_api) (2.12.0)
# Requirement already satisfied: pymatgen-io-validation>=0.1.1 in c:\users\lenovo\anaconda3\lib\site-packages (from emmet-core>=0.87.1->mp_api) (0.1.3)
# Requirement already satisfied: pybtex~=0.24 in c:\users\lenovo\anaconda3\lib\site-packages (from emmet-core>=0.87.1->mp_api) (0.26.1)
# Requirement already satisfied: blake3 in c:\users\lenovo\anaconda3\lib\site-packages (from emmet-core>=0.87.1->mp_api) (1.0.9)
# Requirement already satisfied: inflect in c:\users\lenovo\anaconda3\lib\site-packages (from emmet-core>=0.87.1->mp_api) (7.5.0)
# Requirement already satisfied: pubchempy in c:\users\lenovo\anaconda3\lib\site-packages (from emmet-core>=0.87.1->mp_api) (1.0.5)
# Requirement already satisfied: latexcodec>=1.0.4 in c:\users\lenovo\anaconda3\lib\site-packages (from pybtex~=0.24->emmet-core>=0.87.1->mp_api) (3.0.1)
# Requirement already satisfied: pyyaml>=3.01 in c:\users\lenovo\anaconda3\lib\site-packages (from pybtex~=0.24->emmet-core>=0.87.1->mp_api) (6.0.3)
# Requirement already satisfied: ruamel.yaml in c:\users\lenovo\anaconda3\lib\site-packages (from monty>=2024.12.10->mp_api) (0.18.16)
# Requirement already satisfied: numpy in c:\users\lenovo\anaconda3\lib\site-packages (from monty>=2024.12.10->mp_api) (2.3.5)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic>=2.12->emmet-core>=0.87.1->mp_api) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic>=2.12->emmet-core>=0.87.1->mp_api) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic>=2.12->emmet-core>=0.87.1->mp_api) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic-settings>=2.0->emmet-core>=0.87.1->mp_api) (1.1.0)
# Requirement already satisfied: pymatgen-core>=2026.4.16 in c:\users\lenovo\anaconda3\lib\site-packages (from pymatgen>2024.2.20->mp_api) (2026.7.31)
# Requirement already satisfied: bibtexparser in c:\users\lenovo\anaconda3\lib\site-packages (from pymatgen-core>=2026.4.16->pymatgen>2024.2.20->mp_api) (1.4.4)
# Requirement already satisfied: joblib>=1.3.2 in c:\users\lenovo\anaconda3\lib\site-packages (from pymatgen-core>=2026.4.16->pymatgen>2024.2.20->mp_api) (1.5.2)
# Requirement already satisfied: lxml>=6.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pymatgen-core>=2026.4.16->pymatgen>2024.2.20->mp_api) (6.1.1)
# Requirement already satisfied: matplotlib>=3.8 in c:\users\lenovo\anaconda3\lib\site-packages (from pymatgen-core>=2026.4.16->pymatgen>2024.2.20->mp_api) (3.10.6)
# Requirement already satisfied: networkx>=2.7 in c:\users\lenovo\anaconda3\lib\site-packages (from pymatgen-core>=2026.4.16->pymatgen>2024.2.20->mp_api) (3.5)
# Requirement already satisfied: palettable>=3.3.3 in c:\users\lenovo\anaconda3\lib\site-packages (from pymatgen-core>=2026.4.16->pymatgen>2024.2.20->mp_api) (3.3.3)
# Requirement already satisfied: pandas>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from pymatgen-core>=2026.4.16->pymatgen>2024.2.20->mp_api) (2.3.3)
# Requirement already satisfied: plotly>=5.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pymatgen-core>=2026.4.16->pymatgen>2024.2.20->mp_api) (6.3.0)
# Requirement already satisfied: scipy>=1.13.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pymatgen-core>=2026.4.16->pymatgen>2024.2.20->mp_api) (1.16.3)
# Requirement already satisfied: spglib>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from pymatgen-core>=2026.4.16->pymatgen>2024.2.20->mp_api) (2.7.0)
# Requirement already satisfied: sympy>=1.3 in c:\users\lenovo\anaconda3\lib\site-packages (from pymatgen-core>=2026.4.16->pymatgen>2024.2.20->mp_api) (1.14.0)
# Requirement already satisfied: tabulate>=0.9.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pymatgen-core>=2026.4.16->pymatgen>2024.2.20->mp_api) (0.9.0)
# Requirement already satisfied: tqdm>=4.67.3 in c:\users\lenovo\anaconda3\lib\site-packages (from pymatgen-core>=2026.4.16->pymatgen>2024.2.20->mp_api) (4.70.0)
# Requirement already satisfied: uncertainties>=3.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pymatgen-core>=2026.4.16->pymatgen>2024.2.20->mp_api) (3.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib>=3.8->pymatgen-core>=2026.4.16->pymatgen>2024.2.20->mp_api) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib>=3.8->pymatgen-core>=2026.4.16->pymatgen>2024.2.20->mp_api) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib>=3.8->pymatgen-core>=2026.4.16->pymatgen>2024.2.20->mp_api) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib>=3.8->pymatgen-core>=2026.4.16->pymatgen>2024.2.20->mp_api) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib>=3.8->pymatgen-core>=2026.4.16->pymatgen>2024.2.20->mp_api) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib>=3.8->pymatgen-core>=2026.4.16->pymatgen>2024.2.20->mp_api) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib>=3.8->pymatgen-core>=2026.4.16->pymatgen>2024.2.20->mp_api) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib>=3.8->pymatgen-core>=2026.4.16->pymatgen>2024.2.20->mp_api) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas>=2->pymatgen-core>=2026.4.16->pymatgen>2024.2.20->mp_api) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas>=2->pymatgen-core>=2026.4.16->pymatgen>2024.2.20->mp_api) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\lenovo\anaconda3\lib\site-packages (from plotly>=5.0->pymatgen-core>=2026.4.16->pymatgen>2024.2.20->mp_api) (2.7.0)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.8->pymatgen-core>=2026.4.16->pymatgen>2024.2.20->mp_api) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.23.0->mp_api) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.23.0->mp_api) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.23.0->mp_api) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.23.0->mp_api) (2026.7.22)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from sympy>=1.3->pymatgen-core>=2026.4.16->pymatgen>2024.2.20->mp_api) (1.3.0)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\lib\site-packages (from tqdm>=4.67.3->pymatgen-core>=2026.4.16->pymatgen>2024.2.20->mp_api) (0.4.6)
# Requirement already satisfied: botocore<1.44.0,>=1.43.67 in c:\users\lenovo\anaconda3\lib\site-packages (from boto3->mp_api) (1.43.67)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\lenovo\anaconda3\lib\site-packages (from boto3->mp_api) (1.0.1)
# Requirement already satisfied: s3transfer<0.20.0,>=0.19.0 in c:\users\lenovo\anaconda3\lib\site-packages (from boto3->mp_api) (0.19.2)
# Requirement already satisfied: more_itertools>=8.5.0 in c:\users\lenovo\anaconda3\lib\site-packages (from inflect->emmet-core>=0.87.1->mp_api) (10.8.0)
# Requirement already satisfied: typeguard>=4.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from inflect->emmet-core>=0.87.1->mp_api) (4.6.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in c:\users\lenovo\anaconda3\lib\site-packages (from ruamel.yaml->monty>=2024.12.10->mp_api) (0.2.14)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv
from mp_api.client import MPRester

# %%
# Load environment variables from the .env file
load_dotenv()
api_key = os.getenv("dn4m3hXWoTjwWAt3JHfLIFvExrbFhvkL")

# %%
from mp_api.client import MPRester

api_key = "dn4m3hXWoTjwWAt3JHfLIFvExrbFhvkL"

try:
    with MPRester(api_key) as mpr:
        # Fetch Silicon (mp-149)
        data = mpr.materials.summary.search(
            material_ids=["mp-149"],
            fields=["material_id", "formula_pretty", "band_gap"]
        )

        silicon_entry = data[0]

        print("✅ Authentication Successful!")
        print(f"Material ID: {silicon_entry.material_id}")
        print(f"Formula: {silicon_entry.formula_pretty}")
        print(f"Band Gap: {silicon_entry.band_gap:.2f} eV")

except Exception as e:
    print("❌ Authentication or Query Failed. Check your API key and network connection.")
    print(f"Error details: {e}")
# Out:
# Retrieving SummaryDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# ✅ Authentication Successful!
# Material ID: mp-149
# Formula: Si
# Band Gap: 0.61 eV
